# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('IRIS.csv')

# %%
df.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width            class
# 0           5.1          3.5           1.4          0.2      Iris-setosa
# 1           5.6          2.5           3.9          1.1  Iris-versicolor
# 2           5.9          3.2           4.8          1.8  Iris-versicolor
# 3           6.1          2.8           4.0          1.3  Iris-versicolor
# 4           4.6          3.2           1.4          0.2      Iris-setosa

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class'], dtype='object')

# %%
df['petal_length'].dtypes
# Out:
# dtype('float64')

# %%
df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# class            object
# dtype: object

# %%
df.shape
# Out:
# (150, 5)

# %%
df.size
# Out:
# 750

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=150, step=1),
#  Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class'], dtype='object')]

# %%
df.values
# Out:
# array([[5.1, 3.5, 1.4, 0.2, 'Iris-setosa'],
#        [5.6, 2.5, 3.9, 1.1, 'Iris-versicolor'],
#        [5.9, 3.2, 4.8, 1.8, 'Iris-versicolor'],
#        [6.1, 2.8, 4.0, 1.3, 'Iris-versicolor'],
#        [4.6, 3.2, 1.4, 0.2, 'Iris-setosa'],
#        [5.3, 3.7, 1.5, 0.2, 'Iris-setosa'],
#        [6.4, 3.2, 5.3, 2.3, 'Iris-virginica'],
#        [6.5, 3.0, 5.5, 1.8, 'Iris-virginica'],
#        [7.2, 3.2, 6.0, 1.8, 'Iris-virginica'],
#        [6.2, 2.8, 4.8, 1.8, 'Iris-virginica'],
#        [4.6, 3.1, 1.5, 0.2, 'Iris-setosa'],
#        [5.0, 3.6, 1.4, 0.2, 'Iris-setosaa'],
#        [6.5, 3.0, 5.2, 2.0, 'Iris-virginica'],
#        [6.2, 3.4, 5.4, 2.3, 'Iris-virginica'],
#        [5.9, 3.0, 5.1, 1.8, 'Iris-virginica'],
#        [6.2, 2.2, 4.5, 1.5, 'Iris-versicolor'],
#        [5.4, 3.7, 1.5, 0.2, 'Iris-setosa'],
#        [4.8, 3.4, 1.6, 0.2, 'Iris-setosa'],
#        [4.8, 3.0, 1.4, 0.1, 'Iris-setosa'],
#        [4.3, 3.0, 1.1, 0.1, 'Iris-setosa'],
# ...

# %%
df.rows
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-412feca855b9> in <module>
# ----> 1 df.rows
#
# e:\code\ml\demo\venv\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'rows'

# %%
df.min()
# Out:
# sepal_length           4.3
# sepal_width              2
# petal_length             1
# petal_width            0.1
# class           Iris-setos
# dtype: object

# %%
df.max()
# Out:
# sepal_length               7.9
# sepal_width                4.4
# petal_length               6.9
# petal_width                2.5
# class           Iris-virginica
# dtype: object

# %%
df.mean()
# Out:
# sepal_length    5.843333
# sepal_width     3.054000
# petal_length    3.758667
# petal_width     1.198667
# dtype: float64

# %%
df.median()
# Out:
# sepal_length    5.80
# sepal_width     3.00
# petal_length    4.35
# petal_width     1.30
# dtype: float64

# %%
df.std()
# Out:
# sepal_length    0.828066
# sepal_width     0.433594
# petal_length    1.764420
# petal_width     0.763161
# dtype: float64

# %%
df.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width            class
# 0           5.1          3.5           1.4          0.2      Iris-setosa
# 1           5.6          2.5           3.9          1.1  Iris-versicolor
# 2           5.9          3.2           4.8          1.8  Iris-versicolor
# 3           6.1          2.8           4.0          1.3  Iris-versicolor
# 4           4.6          3.2           1.4          0.2      Iris-setosa

# %%
df.tail(5)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width            class
# 145           6.4          3.1           5.5          1.8   Iris-virginica
# 146           6.0          3.0           4.8          1.8   Iris-virginica
# 147           5.0          3.3           1.4          0.2      Iris-setosa
# 148           7.0          3.2           4.7          1.4  Iris-versicolor
# 149           6.4          3.2           4.5          1.5  Iris-versicolor

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.sample(5)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width            class
# 24            4.9          3.1           1.5          0.1      Iris-setosa
# 119           4.9          2.5           4.5          1.7   Iris-virginica
# 111           5.5          2.6           4.4          1.2  Iris-versicolor
# 16            5.4          3.7           1.5          0.2      Iris-setosa
# 83            6.0          2.2           4.0          1.0  Iris-versicolor

# %%
df.dropna()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width            class
# 0             5.1          3.5           1.4          0.2      Iris-setosa
# 1             5.6          2.5           3.9          1.1  Iris-versicolor
# 2             5.9          3.2           4.8          1.8  Iris-versicolor
# 3             6.1          2.8           4.0          1.3  Iris-versicolor
# 4             4.6          3.2           1.4          0.2      Iris-setosa
# 5             5.3          3.7           1.5          0.2      Iris-setosa
# 6             6.4          3.2           5.3          2.3   Iris-virginica
# 7             6.5          3.0           5.5          1.8   Iris-virginica
# 8             7.2          3.2           6.0          1.8   Iris-virginica
# 9             6.2          2.8           4.8          1.8   Iris-virginica
# 10            4.6          3.1           1.5          0.2      Iris-setosa
# ...

# %%
df.head(50).mean()
# Out:
# sepal_length    5.748
# sepal_width     3.182
# petal_length    3.366
# petal_width     1.074
# dtype: float64

# %%
df.mean()
# Out:
# sepal_length    5.843333
# sepal_width     3.054000
# petal_length    3.758667
# petal_width     1.198667
# dtype: float64

# %%
df['sepal_length'].describe()
# Out:
# count    150.000000
# mean       5.843333
# std        0.828066
# min        4.300000
# 25%        5.100000
# 50%        5.800000
# 75%        6.400000
# max        7.900000
# Name: sepal_length, dtype: float64

# %%
df.sepal_length.describe()
# Out:
# count    150.000000
# mean       5.843333
# std        0.828066
# min        4.300000
# 25%        5.100000
# 50%        5.800000
# 75%        6.400000
# max        7.900000
# Name: sepal_length, dtype: float64

# %%
df.sepal_length.count()
# Out:
# 150

# %%
df.sepal_length.mean()
# Out:
# 5.843333333333334

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class'], dtype='object')

# %%
df[['sepal_length','sepal_width']]
# Out:
#      sepal_length  sepal_width
# 0             5.1          3.5
# 1             5.6          2.5
# 2             5.9          3.2
# 3             6.1          2.8
# 4             4.6          3.2
# 5             5.3          3.7
# 6             6.4          3.2
# 7             6.5          3.0
# 8             7.2          3.2
# 9             6.2          2.8
# 10            4.6          3.1
# 11            5.0          3.6
# 12            6.5          3.0
# 13            6.2          3.4
# 14            5.9          3.0
# 15            6.2          2.2
# 16            5.4          3.7
# 17            4.8          3.4
# 18            4.8          3.0
# 19            4.3          3.0
# 20            5.8          4.0
# 21            6.9          3.1
# 22            6.7          3.1
# 23            4.4          2.9
# 24            4.9          3.1
# 25            4.9          3.0
# 26            4.7          3.2
# 27            6.7          3.3
# 28            6.7          3.0
# ...

# %%
df[10:20][['sepal_length','sepal_width']]
# Out:
#     sepal_length  sepal_width
# 10           4.6          3.1
# 11           5.0          3.6
# 12           6.5          3.0
# 13           6.2          3.4
# 14           5.9          3.0
# 15           6.2          2.2
# 16           5.4          3.7
# 17           4.8          3.4
# 18           4.8          3.0
# 19           4.3          3.0

# %%
df.loc[10:20,['sepal_length','sepal_width']]
# Out:
#     sepal_length  sepal_width
# 10           4.6          3.1
# 11           5.0          3.6
# 12           6.5          3.0
# 13           6.2          3.4
# 14           5.9          3.0
# 15           6.2          2.2
# 16           5.4          3.7
# 17           4.8          3.4
# 18           4.8          3.0
# 19           4.3          3.0
# 20           5.8          4.0

# %%
df.iloc[10:20,[0,1,2,3,4]]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width            class
# 10           4.6          3.1           1.5          0.2      Iris-setosa
# 11           5.0          3.6           1.4          0.2     Iris-setosaa
# 12           6.5          3.0           5.2          2.0   Iris-virginica
# 13           6.2          3.4           5.4          2.3   Iris-virginica
# 14           5.9          3.0           5.1          1.8   Iris-virginica
# 15           6.2          2.2           4.5          1.5  Iris-versicolor
# 16           5.4          3.7           1.5          0.2      Iris-setosa
# 17           4.8          3.4           1.6          0.2      Iris-setosa
# 18           4.8          3.0           1.4          0.1      Iris-setosa
# 19           4.3          3.0           1.1          0.1      Iris-setosa

# %%
zdf=pd.read_csv('zoo.csv')

# %%
zdf.head(5)
# Out:
#   animal_name  hair  feathers  eggs  milk  airborne  aquatic  predator  \
# 0    aardvark     1         0     0     1         0        0         1
# 1    antelope     1         0     0     1         0        0         0
# 2        bass     0         0     1     0         0        1         1
# 3        bear     1         0     0     1         0        0         1
# 4        boar     1         0     0     1         0        0         1
#
#    toothed  backbone  breathes  venomous  fins  legs  tail  domestic  catsize  \
# 0        1         1         1         0     0     4     0         0        1
# 1        1         1         1         0     0     4     1         0        1
# 2        1         1         0         0     1     0     1         0        0
# 3        1         1         1         0     0     4     0         0        1
# 4        1         1         1         0     0     4     1         0        1
#
#    class
# 0      1
# 1      1
# 2      4
# 3      1
# 4      1

# %%
zdf.dtypes
# Out:
# animal_name    object
# hair            int64
# feathers        int64
# eggs            int64
# milk            int64
# airborne        int64
# aquatic         int64
# predator        int64
# toothed         int64
# backbone        int64
# breathes        int64
# venomous        int64
# fins            int64
# legs            int64
# tail            int64
# domestic        int64
# catsize         int64
# class           int64
# dtype: object

# %%
zdf[zdf.isnull().any(axis=1)].head()
# Out:
# Empty DataFrame
# Columns: [animal_name, hair, feathers, eggs, milk, airborne, aquatic, predator, toothed, backbone, breathes, venomous, fins, legs, tail, domestic, catsize, class]
# Index: []

# %%
flights=pd.read_csv("ttp://rcs.bu.edu/examples/python/data_analysis/flights.csv""http://rcs.bu.edu/examples/python/data_analysis/flights.csv""http://rcs.bu.edu/examples/python/data_analysis/flights.csv""http://rcs.bu.edu/examples/python/data_analysis/flights.csv""http://rcs.bu.edu/examples/python/data_analysis/flights.csv""http://rcs.bu.edu/examples/python/data_analysis/flights.csv""http://rcs.bu.edu/examples/python/data_analysis/flights.csv""http://rcs.bu.edu/examples/python/data_analysis/flights.csv""http://rcs.bu.edu/examples/python/data_analysis/flights.csv""http://rcs.bu.edu/examples/python/data_analysis/flights.csv""http://rcs.bu.edu/examples/python/data_analysis/flights.csv""http://rcs.bu.edu/examples/python/data_analysis/flights.csv""http://rcs.bu.edu/examples/python/data_analysis/flights.csv""http://rcs.bu.edu/examples/python/data_analysis/flights.csv""http://rcs.bu.edu/examples/python/data_analysis/flights.csv""http://rcs.bu.edu/examples/python/data_analysis/flights.csv""http://rcs.bu.edu/examples/python/data_analysis/flights.csv""http://rcs.bu.edu/examples/python/data_analysis/flights.csv""http://rcs.bu.edu/examples/python/data_analysis/flights.csv""http://rcs.bu.edu/examples/python/data_analysis/flights.csv""http://rcs.bu.edu/examples/python/data_analysis/flights.csv""http://rcs.bu.edu/examples/python/data_analysis/flights.csv""http://rcs.bu.edu/examples/python/data_analysis/flights.csv""http://rcs.bu.edu/examples/python/data_analysis/flights.csv""http://rcs.bu.edu/examples/python/data_analysis/flights.csv""http://rcs.bu.edu/examples/python/data_analysis/flights.csv""http://rcs.bu.edu/examples/python/data_analysis/flights.csv""http://rcs.bu.edu/examples/python/data_analysis/flights.csv""http://rcs.bu.edu/examples/python/data_analysis/flights.csv""http://rcs.bu.edu/examples/python/data_analysis/flights.csv""http://rcs.bu.edu/examples/python/data_analysis/flights.csv""http://rcs.bu.edu/examples/python/data_analysis/flights.csv""http://rcs.bu.edu/examples/python/data_analysis/flights.csv""http://rcs.bu.edu/examples/python/data_analysis/flights.csv""http://rcs.bu.edu/examples/python/data_analysis/flights.csv""http://rcs.bu.edu/examples/python/data_analysis/flights.csv""http://rcs.bu.edu/examples/python/data_analysis/flights.csv""http://rcs.bu.edu/examples/python/data_analysis/flights.csv""http://rcs.bu.edu/examples/python/data_analysis/flights.csv""http://rcs.bu.edu/examples/python/data_analysis/flights.csv""http://rcs.bu.edu/examples/python/data_analysis/flights.csv""http://rcs.bu.edu/examples/python/data_analysis/flights.csv""http://rcs.bu.edu/examples/python/data_analysis/flights.csv""http://rcs.bu.edu/examples/python/data_analysis/flights.csv""http://rcs.bu.edu/examples/python/data_analysis/flights.csv""http://rcs.bu.edu/examples/python/data_analysis/flights.csv""http://rcs.bu.edu/examples/python/data_analysis/flights.csv""http://rcs.bu.edu/examples/python/data_analysis/flights.csv""http://rcs.bu.edu/examples/python/data_analysis/flights.csv""http://rcs.bu.edu/examples/python/data_analysis/flights.csv""http://rcs.bu.edu/examples/python/data_analysis/flights.csv""http://rcs.bu.edu/examples/python/data_analysis/flights.csv""http://rcs.bu.edu/examples/python/data_analysis/flights.csv""http://rcs.bu.edu/examples/python/data_analysis/flights.csv""http://rcs.bu.edu/examples/python/data_analysis/flights.csv""http://rcs.bu.edu/examples/python/data_analysis/flights.csv""http://rcs.bu.edu/examples/python/data_analysis/flights.csv""http://rcs.bu.edu/examples/python/data_analysis/flights.csv""http://rcs.bu.edu/examples/python/data_analysis/flights.csv"")
# Out:
#   File "<ipython-input-53-1dff69077542>", line 1
# ...

# %%
dt=pd.read_csv("http://rcs.bu.edu/examples/python/data_analysis/flights.csv")

# %%
dt.head()
# Out:
#    year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier tailnum  \
# 0  2013      1    1     517.0        2.0     830.0       11.0      UA  N14228
# 1  2013      1    1     533.0        4.0     850.0       20.0      UA  N24211
# 2  2013      1    1     542.0        2.0     923.0       33.0      AA  N619AA
# 3  2013      1    1     554.0       -6.0     812.0      -25.0      DL  N668DN
# 4  2013      1    1     554.0       -4.0     740.0       12.0      UA  N39463
#
#    flight origin dest  air_time  distance  hour  minute
# 0    1545    EWR  IAH     227.0      1400   5.0    17.0
# 1    1714    LGA  IAH     227.0      1416   5.0    33.0
# 2    1141    JFK  MIA     160.0      1089   5.0    42.0
# 3     461    LGA  ATL     116.0       762   5.0    54.0
# 4    1696    EWR  ORD     150.0       719   5.0    54.0

# %%
dt.dtypes
# Out:
# year           int64
# month          int64
# day            int64
# dep_time     float64
# dep_delay    float64
# arr_time     float64
# arr_delay    float64
# carrier       object
# tailnum       object
# flight         int64
# origin        object
# dest          object
# air_time     float64
# distance       int64
# hour         float64
# minute       float64
# dtype: object

# %%
dt.axes
# Out:
# [RangeIndex(start=0, stop=160754, step=1),
#  Index(['year', 'month', 'day', 'dep_time', 'dep_delay', 'arr_time',
#         'arr_delay', 'carrier', 'tailnum', 'flight', 'origin', 'dest',
#         'air_time', 'distance', 'hour', 'minute'],
#        dtype='object')]

# %%
dt.columns
# Out:
# Index(['year', 'month', 'day', 'dep_time', 'dep_delay', 'arr_time',
#        'arr_delay', 'carrier', 'tailnum', 'flight', 'origin', 'dest',
#        'air_time', 'distance', 'hour', 'minute'],
#       dtype='object')

# %%
dt[dt.isnull().any(axis=1)].head()
# Out:
#      year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 330  2013      1    1    1807.0       29.0    2251.0        NaN      UA
# 403  2013      1    1       NaN        NaN       NaN        NaN      AA
# 404  2013      1    1       NaN        NaN       NaN        NaN      AA
# 855  2013      1    2    2145.0       16.0       NaN        NaN      UA
# 858  2013      1    2       NaN        NaN       NaN        NaN      AA
#
#     tailnum  flight origin dest  air_time  distance  hour  minute
# 330  N31412    1228    EWR  SAN       NaN      2425  18.0     7.0
# 403  N3EHAA     791    LGA  DFW       NaN      1389   NaN     NaN
# 404  N3EVAA    1925    LGA  MIA       NaN      1096   NaN     NaN
# 855  N12221    1299    EWR  RSW       NaN      1068  21.0    45.0
# 858     NaN     133    JFK  LAX       NaN      2475   NaN     NaN

# %%
dt[dt.isnull().any(axis=1)].head()
# Out:
#      year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 330  2013      1    1    1807.0       29.0    2251.0        NaN      UA
# 403  2013      1    1       NaN        NaN       NaN        NaN      AA
# 404  2013      1    1       NaN        NaN       NaN        NaN      AA
# 855  2013      1    2    2145.0       16.0       NaN        NaN      UA
# 858  2013      1    2       NaN        NaN       NaN        NaN      AA
#
#     tailnum  flight origin dest  air_time  distance  hour  minute
# 330  N31412    1228    EWR  SAN       NaN      2425  18.0     7.0
# 403  N3EHAA     791    LGA  DFW       NaN      1389   NaN     NaN
# 404  N3EVAA    1925    LGA  MIA       NaN      1096   NaN     NaN
# 855  N12221    1299    EWR  RSW       NaN      1068  21.0    45.0
# 858     NaN     133    JFK  LAX       NaN      2475   NaN     NaN

# %%
dt.head(331)
# Out:
#      year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 0    2013      1    1     517.0        2.0     830.0       11.0      UA
# 1    2013      1    1     533.0        4.0     850.0       20.0      UA
# 2    2013      1    1     542.0        2.0     923.0       33.0      AA
# 3    2013      1    1     554.0       -6.0     812.0      -25.0      DL
# 4    2013      1    1     554.0       -4.0     740.0       12.0      UA
# 5    2013      1    1     558.0       -2.0     753.0        8.0      AA
# 6    2013      1    1     558.0       -2.0     924.0        7.0      UA
# 7    2013      1    1     558.0       -2.0     923.0      -14.0      UA
# 8    2013      1    1     559.0       -1.0     941.0       31.0      AA
# 9    2013      1    1     559.0       -1.0     854.0       -8.0      UA
# 10   2013      1    1     602.0       -8.0     812.0       -8.0      DL
# 11   2013      1    1     606.0       -4.0     858.0      -12.0      AA
# ...

# %%
dt.dropna()
# Out:
#         year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 0       2013      1    1     517.0        2.0     830.0       11.0      UA
# 1       2013      1    1     533.0        4.0     850.0       20.0      UA
# 2       2013      1    1     542.0        2.0     923.0       33.0      AA
# 3       2013      1    1     554.0       -6.0     812.0      -25.0      DL
# 4       2013      1    1     554.0       -4.0     740.0       12.0      UA
# 5       2013      1    1     558.0       -2.0     753.0        8.0      AA
# 6       2013      1    1     558.0       -2.0     924.0        7.0      UA
# 7       2013      1    1     558.0       -2.0     923.0      -14.0      UA
# 8       2013      1    1     559.0       -1.0     941.0       31.0      AA
# 9       2013      1    1     559.0       -1.0     854.0       -8.0      UA
# 10      2013      1    1     602.0       -8.0     812.0       -8.0      DL
# ...

# %%
dt[dt.isnull().any(axis=1)].head
# Out:
# <bound method NDFrame.head of         year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 330     2013      1    1    1807.0       29.0    2251.0        NaN      UA
# 403     2013      1    1       NaN        NaN       NaN        NaN      AA
# 404     2013      1    1       NaN        NaN       NaN        NaN      AA
# 855     2013      1    2    2145.0       16.0       NaN        NaN      UA
# 858     2013      1    2       NaN        NaN       NaN        NaN      AA
# 859     2013      1    2       NaN        NaN       NaN        NaN      AA
# 860     2013      1    2       NaN        NaN       NaN        NaN      UA
# 1067    2013      1    3    1348.0       -2.0    1821.0        NaN      DL
# 1275    2013      1    3       NaN        NaN       NaN        NaN      AA
# 1276    2013      1    3       NaN        NaN       NaN        NaN      AA
# 1277    2013      1    3       NaN        NaN       NaN        NaN      AA
# ...

# %%
dt.shape
# Out:
# (160754, 16)

# %%
mdt=dt.dropna()

# %%
mdt.shape
# Out:
# (157927, 16)

# %%
mdt=dt.dropna(how='all')

# %%
mdt.shape
# Out:
# (160754, 16)

# %%
mdt=dt.dropna(axis=1)

# %%
mdt.columns
# Out:
# Index(['year', 'month', 'day', 'carrier', 'flight', 'origin', 'dest',
#        'distance'],
#       dtype='object')

# %%
mdt.shape
# Out:
# (160754, 8)

# %%
dtm=dt.isnull()

# %%
dtm.head(331)
# Out:
#       year  month    day  dep_time  dep_delay  arr_time  arr_delay  carrier  \
# 0    False  False  False     False      False     False      False    False
# 1    False  False  False     False      False     False      False    False
# 2    False  False  False     False      False     False      False    False
# 3    False  False  False     False      False     False      False    False
# 4    False  False  False     False      False     False      False    False
# 5    False  False  False     False      False     False      False    False
# 6    False  False  False     False      False     False      False    False
# 7    False  False  False     False      False     False      False    False
# 8    False  False  False     False      False     False      False    False
# 9    False  False  False     False      False     False      False    False
# 10   False  False  False     False      False     False      False    False
# ...

# %%
mdt=dt.fillna(dt.mean())

# %%
mdt.head(331)
# Out:
#      year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 0    2013      1    1     517.0        2.0     830.0  11.000000      UA
# 1    2013      1    1     533.0        4.0     850.0  20.000000      UA
# 2    2013      1    1     542.0        2.0     923.0  33.000000      AA
# 3    2013      1    1     554.0       -6.0     812.0 -25.000000      DL
# 4    2013      1    1     554.0       -4.0     740.0  12.000000      UA
# 5    2013      1    1     558.0       -2.0     753.0   8.000000      AA
# 6    2013      1    1     558.0       -2.0     924.0   7.000000      UA
# 7    2013      1    1     558.0       -2.0     923.0 -14.000000      UA
# 8    2013      1    1     559.0       -1.0     941.0  31.000000      AA
# 9    2013      1    1     559.0       -1.0     854.0  -8.000000      UA
# 10   2013      1    1     602.0       -8.0     812.0  -8.000000      DL
# 11   2013      1    1     606.0       -4.0     858.0 -12.000000      AA
# ...
